# %%
# %sql
CREATE TABLE gold_trip_progress
USING DELTA
LOCATION 'abfss://gold@travelappprojectstorage.dfs.core.windows.net/trip_adherence/gold_trip_progress';

# %%
# %sql

CREATE TABLE gold_schedule_adherence
USING DELTA
LOCATION 'abfss://gold@travelappprojectstorage.dfs.core.windows.net/trip_adherence/gold_schedule_adherence';

CREATE TABLE gold_trip_summary
USING DELTA
LOCATION 'abfss://gold@travelappprojectstorage.dfs.core.windows.net/trip_adherence/gold_trip_summary';

# %%
# %sql
CREATE TABLE gold_agency_trip_performance
USING DELTA
LOCATION 'abfss://gold@travelappprojectstorage.dfs.core.windows.net/trip_adherence/gold_agency_trip_performance';
